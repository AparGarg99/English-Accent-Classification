# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report 
from pycm import ConfusionMatrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.linear_model import Perceptron
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Standardized_Features.csv')
data.head()
# Out:
#      mfcc_1    mfcc_2    mfcc_3    mfcc_4    mfcc_5    mfcc_6    mfcc_7  \
# 0  0.282728 -0.474545 -1.431620 -0.838590 -1.296439 -1.893429 -1.771372
# 1  1.193171 -1.450861  0.000711 -0.790228  1.279287  0.755650  0.901923
# 2 -1.034973  0.627078  0.199520  0.998984 -0.784622  1.528109 -0.577994
# 3  1.384008  0.560417  0.667361 -0.254236  0.610491  0.620806  0.811242
# 4  0.934085  2.136934 -2.251532  0.690264 -1.076940 -0.852905  0.001930
#
#      mfcc_8    mfcc_9   mfcc_10   mfcc_11   mfcc_12   mfcc_13  chroma_stft  \
# 0 -0.975644 -1.693050 -0.905051 -2.385454 -0.195656 -1.897900    -0.203286
# 1  1.356368  2.278842  1.350389  1.535524  1.345042  1.197492     1.985103
# 2  1.107375 -0.706535  0.982741 -0.397005 -0.912998  0.486108    -1.381268
# 3  0.099781 -0.245145  1.018141 -0.216337  2.221808  0.605855     0.687013
# 4 -0.603969  0.854139  0.591720  0.474665 -1.057779  0.405189    -1.209908
#
#    spectral_centroid  spectral_bandwidth   rolloff  zero_crossing_rate  label
# 0           0.483809           -0.393816  0.077136            0.846385      1
# 1           1.772678            1.661541  1.866492            0.415296      0
# 2          -0.979375           -1.090882 -1.125755           -1.226060      0
# 3          -0.664155           -0.353625 -0.733579           -0.766253      1
# 4          -1.625381           -1.950325 -1.546935           -1.381914      0

# %%
labels = ['Logistic Regression', 'Decision Tree (Gini)','Decision Tree (Entropy)', 'SVM Classifier', 'Random Forest','Perceptron', 'MLP Classifier']
clf1 = LogisticRegression()
clf2=DecisionTreeClassifier(criterion = "gini")
clf3=DecisionTreeClassifier(criterion = "entropy")
clf4=SVC()
clf5=RandomForestClassifier()
clf6=Perceptron()
clf7=MLPClassifier()
models=[clf1,clf2,clf3,clf4,clf5,clf6,clf7]

def train(X,y=data['label']):
    for clf, label in zip(models, labels):
        scores = cross_val_score(clf, X, y, cv=10,scoring='accuracy')
        print("Accuracy: %0.2f (+/- %0.2f) [%s]"
              % (scores.mean(), scores.std(), label))

# %%
# On MFCC features only
train(data.iloc[:,:13])
# Out:
# Accuracy: 0.62 (+/- 0.01) [Logistic Regression]
# Accuracy: 0.71 (+/- 0.01) [Decision Tree (Gini)]
# Accuracy: 0.72 (+/- 0.01) [Decision Tree (Entropy)]
# Accuracy: 0.78 (+/- 0.01) [SVM Classifier]
# Accuracy: 0.79 (+/- 0.01) [Random Forest]
# Accuracy: 0.53 (+/- 0.03) [Perceptron]
# Accuracy: 0.78 (+/- 0.01) [MLP Classifier]

# %%
# On All features except MFCC
train(data.iloc[:,13:-1])
# Out:
# Accuracy: 0.57 (+/- 0.01) [Logistic Regression]
# Accuracy: 0.57 (+/- 0.01) [Decision Tree (Gini)]
# Accuracy: 0.58 (+/- 0.01) [Decision Tree (Entropy)]
# Accuracy: 0.59 (+/- 0.01) [SVM Classifier]
# Accuracy: 0.61 (+/- 0.01) [Random Forest]
# Accuracy: 0.51 (+/- 0.02) [Perceptron]
# Accuracy: 0.61 (+/- 0.01) [MLP Classifier]

# %%
# On All features
train(data.iloc[:,:-1])
# Out:
# Accuracy: 0.62 (+/- 0.01) [Logistic Regression]
# Accuracy: 0.72 (+/- 0.01) [Decision Tree (Gini)]
# Accuracy: 0.73 (+/- 0.01) [Decision Tree (Entropy)]
# Accuracy: 0.78 (+/- 0.01) [SVM Classifier]
# Accuracy: 0.79 (+/- 0.01) [Random Forest]
# Accuracy: 0.54 (+/- 0.02) [Perceptron]
# Accuracy: 0.80 (+/- 0.00) [MLP Classifier]

# %%
# From above, we see that SVC, Random Forest and MLP Classifier give best results
# We get best results on All features

# %%
# Function to calculate accuracy 
def cal_accuracy(y_test, y_pred): 
    print ("Accuracy : ", accuracy_score(y_test,y_pred)*100) 
    print("Report : ", classification_report(y_test, y_pred)) 
    print(ConfusionMatrix(actual_vector=list(y_test),predict_vector=list(y_pred)))

# %%
# MLP
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:,:-1],data['label'], test_size=0.10, random_state=42)
clf7.fit(X_train, y_train)
y_pred = clf7.predict(X_test)
cal_accuracy(y_test, y_pred)
# Out:
# Accuracy :  79.33836331979106
# Report :                precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       938
#            1       0.80      0.73      0.76       785
#
#     accuracy                           0.79      1723
#    macro avg       0.79      0.79      0.79      1723
# weighted avg       0.79      0.79      0.79      1723
#
# Predict   0         1
# Actual
# 0         794       144
#
# 1         212       573
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.77427,0.8125)
# ACC Macro                                                         0.79338
# ARI                                                               0.34378
# AUNP                                                              0.78821
# AUNU                                                              0.78821
# Bennett S                                                         0.58677
# CBA                                                               0.7596
# CSI                                                               0.58242
# Chi-Squared                                                       584.40777
# Chi-Squared DF                                                    1
# Conditional Entropy                                               0.72017
# Cramer V                                                          0.58239
# Cross Entropy                                                     0.99889
# F1 Macro                                                          0.78993
# F1 Micro                                                          0.79338
# FNR Macro                                                         0.21179
# FNR Micro                                                         0.20662
# FPR Macro                                                         0.21179
# FPR Micro                                                         0.20662
# Gwet AC1                                                          0.59346
# Hamming Loss                                                      0.20662
# Joint Entropy                                                     1.71447
# KL Divergence                                                     0.00459
# Kappa                                                             0.58052
# Kappa 95% CI                                                      (0.54171,0.61933)
# Kappa No Prevalence                                               0.58677
# Kappa Standard Error                                              0.0198
# Kappa Unbiased                                                    0.57986
# Lambda A                                                          0.5465
# Lambda B                                                          0.50349
# Mutual Information                                                0.25944
# NIR                                                               0.5444
# Overall ACC                                                       0.79338
# Overall CEN                                                       0.66872
# Overall J                                                         (1.30723,0.65361)
# Overall MCC                                                       0.58239
# Overall MCEN                                                      0.51887
# Overall RACC                                                      0.50745
# Overall RACCU                                                     0.50823
# P-Value                                                           None
# PPV Macro                                                         0.79421
# PPV Micro                                                         0.79338
# Pearson C                                                         0.50326
# Phi-Squared                                                       0.33918
# RCI                                                               0.26093
# RR                                                                861.5
# Reference Entropy                                                 0.9943
# Response Entropy                                                  0.97961
# SOA1(Landis & Koch)                                               Moderate
# SOA2(Fleiss)                                                      Intermediate to Good
# SOA3(Altman)                                                      Moderate
# SOA4(Cicchetti)                                                   Fair
# SOA5(Cramer)                                                      Relatively Strong
# SOA6(Matthews)                                                    Moderate
# Scott PI                                                          0.57986
# Standard Error                                                    0.00975
# TNR Macro                                                         0.78821
# TNR Micro                                                         0.79338
# TPR Macro                                                         0.78821
# TPR Micro                                                         0.79338
# Zero-one Loss                                                     356
#
# Class Statistics :
#
# Classes                                                           0             1
# ACC(Accuracy)                                                     0.79338       0.79338
# AGF(Adjusted F-score)                                             0.80895       0.77091
# AGM(Adjusted geometric mean)                                      0.76849       0.80735
# AM(Difference between automatic and manual classification)        68            -68
# AUC(Area under the ROC curve)                                     0.78821       0.78821
# AUCI(AUC value interpretation)                                    Good          Good
# AUPR(Area under the PR curve)                                     0.81787       0.76455
# BCD(Bray-Curtis dissimilarity)                                    0.01973       0.01973
# BM(Informedness or bookmaker informedness)                        0.57642       0.57642
# CEN(Confusion entropy)                                            0.62677       0.72301
# DOR(Diagnostic odds ratio)                                        14.90311      14.90311
# DP(Discriminant power)                                            0.64686       0.64686
# DPI(Discriminant power interpretation)                            Poor          Poor
# ERR(Error rate)                                                   0.20662       0.20662
# F0.5(F0.5 score)                                                  0.80008       0.78429
# F1(F1 score - harmonic mean of precision and sensitivity)         0.81687       0.76298
# F2(F2 score)                                                      0.83438       0.74281
# FDR(False discovery rate)                                         0.21074       0.20084
# FN(False negative/miss/type 2 error)                              144           212
# FNR(Miss rate or false negative rate)                             0.15352       0.27006
# FOR(False omission rate)                                          0.20084       0.21074
# FP(False positive/type 1 error/false alarm)                       212           144
# FPR(Fall-out or false positive rate)                              0.27006       0.15352
# G(G-measure geometric mean of precision and sensitivity)          0.81737       0.76377
# GI(Gini index)                                                    0.57642       0.57642
# GM(G-mean geometric mean of specificity and sensitivity)          0.78605       0.78605
# IBA(Index of balanced accuracy)                                   0.68989       0.54587
# ICSI(Individual classification success index)                     0.63575       0.5291
# IS(Information score)                                             0.53584       0.81072
# J(Jaccard index)                                                  0.69043       0.61679
# LS(Lift score)                                                    1.44979       1.75409
# MCC(Matthews correlation coefficient)                             0.58239       0.58239
# MCCI(Matthews correlation coefficient interpretation)             Moderate      Moderate
# MCEN(Modified confusion entropy)                                  0.82505       0.90334
# MK(Markedness)                                                    0.58843       0.58843
# N(Condition negative)                                             785           938
# NLR(Negative likelihood ratio)                                    0.21032       0.31904
# NLRI(Negative likelihood ratio interpretation)                    Poor          Poor
# NPV(Negative predictive value)                                    0.79916       0.78926
# OC(Overlap coefficient)                                           0.84648       0.79916
# OOC(Otsuka-Ochiai coefficient)                                    0.81737       0.76377
# OP(Optimized precision)                                           0.71945       0.71945
# P(Condition positive or support)                                  938           785
# PLR(Positive likelihood ratio)                                    3.13438       4.75472
# PLRI(Positive likelihood ratio interpretation)                    Poor          Poor
# POP(Population)                                                   1723          1723
# PPV(Precision or positive predictive value)                       0.78926       0.79916
# PRE(Prevalence)                                                   0.5444        0.4556
# Q(Yule Q - coefficient of colligation)                            0.87424       0.87424
# QI(Yule Q interpretation)                                         Strong        Strong
# RACC(Random accuracy)                                             0.31786       0.18959
# RACCU(Random accuracy unbiased)                                   0.31825       0.18998
# TN(True negative/correct rejection)                               573           794
# TNR(Specificity or true negative rate)                            0.72994       0.84648
# TON(Test outcome negative)                                        717           1006
# TOP(Test outcome positive)                                        1006          717
# TP(True positive/hit)                                             794           573
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.84648       0.72994
# Y(Youden index)                                                   0.57642       0.57642
# dInd(Distance index)                                              0.31065       0.31065
# sInd(Similarity index)                                            0.78034       0.78034

# %%
# Random Forest
clf5.fit(X_train, y_train)
y_pred = clf5.predict(X_test)
cal_accuracy(y_test, y_pred)
# Out:
# Accuracy :  78.11955890887987
# Report :                precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81       938
#            1       0.82      0.67      0.74       785
#
#     accuracy                           0.78      1723
#    macro avg       0.79      0.77      0.77      1723
# weighted avg       0.79      0.78      0.78      1723
#
# Predict   0         1
# Actual
# 0         819       119
#
# 1         258       527
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.76167,0.80072)
# ACC Macro                                                         0.7812
# ARI                                                               0.31558
# AUNP                                                              0.77224
# AUNU                                                              0.77224
# Bennett S                                                         0.56239
# CBA                                                               0.71589
# CSI                                                               0.56035
# Chi-Squared                                                       540.58066
# Chi-Squared DF                                                    1
# Conditional Entropy                                               0.71497
# Cramer V                                                          0.56013
# Cross Entropy                                                     1.01387
# F1 Macro                                                          0.77473
# F1 Micro                                                          0.7812
# FNR Macro                                                         0.22776
# FNR Micro                                                         0.2188
# FPR Macro                                                         0.22776
# FPR Micro                                                         0.2188
# Gwet AC1                                                          0.57461
# Hamming Loss                                                      0.2188
# Joint Entropy                                                     1.70928
# KL Divergence                                                     0.01957
# Kappa                                                             0.55245
# Kappa 95% CI                                                      (0.51252,0.59238)
# Kappa No Prevalence                                               0.56239
# Kappa Standard Error                                              0.02037
# Kappa Unbiased                                                    0.54945
# Lambda A                                                          0.51975
# Lambda B                                                          0.41641
# Mutual Information                                                0.23941
# NIR                                                               0.5444
# Overall ACC                                                       0.7812
# Overall CEN                                                       0.67192
# Overall J                                                         (1.26775,0.63387)
# Overall MCC                                                       0.56013
# Overall MCEN                                                      0.51709
# Overall RACC                                                      0.51111
# Overall RACCU                                                     0.51436
# P-Value                                                           None
# PPV Macro                                                         0.78812
# PPV Micro                                                         0.7812
# Pearson C                                                         0.48869
# Phi-Squared                                                       0.31374
# RCI                                                               0.24078
# RR                                                                861.5
# Reference Entropy                                                 0.9943
# Response Entropy                                                  0.95438
# SOA1(Landis & Koch)                                               Moderate
# SOA2(Fleiss)                                                      Intermediate to Good
# SOA3(Altman)                                                      Moderate
# SOA4(Cicchetti)                                                   Fair
# SOA5(Cramer)                                                      Relatively Strong
# SOA6(Matthews)                                                    Moderate
# Scott PI                                                          0.54945
# Standard Error                                                    0.00996
# TNR Macro                                                         0.77224
# TNR Micro                                                         0.7812
# TPR Macro                                                         0.77224
# TPR Micro                                                         0.7812
# Zero-one Loss                                                     377
#
# Class Statistics :
#
# Classes                                                           0             1
# ACC(Accuracy)                                                     0.7812        0.7812
# AGF(Adjusted F-score)                                             0.8144        0.73708
# AGM(Adjusted geometric mean)                                      0.73611       0.80352
# AM(Difference between automatic and manual classification)        139           -139
# AUC(Area under the ROC curve)                                     0.77224       0.77224
# AUCI(AUC value interpretation)                                    Good          Good
# AUPR(Area under the PR curve)                                     0.81679       0.74356
# BCD(Bray-Curtis dissimilarity)                                    0.04034       0.04034
# BM(Informedness or bookmaker informedness)                        0.54447       0.54447
# CEN(Confusion entropy)                                            0.62074       0.74398
# DOR(Diagnostic odds ratio)                                        14.05814      14.05814
# DP(Discriminant power)                                            0.63289       0.63289
# DPI(Discriminant power interpretation)                            Poor          Poor
# ERR(Error rate)                                                   0.2188        0.2188
# F0.5(F0.5 score)                                                  0.78059       0.78213
# F1(F1 score - harmonic mean of precision and sensitivity)         0.8129        0.73655
# F2(F2 score)                                                      0.848         0.69599
# FDR(False discovery rate)                                         0.23955       0.18421
# FN(False negative/miss/type 2 error)                              119           258
# FNR(Miss rate or false negative rate)                             0.12687       0.32866
# FOR(False omission rate)                                          0.18421       0.23955
# FP(False positive/type 1 error/false alarm)                       258           119
# FPR(Fall-out or false positive rate)                              0.32866       0.12687
# G(G-measure geometric mean of precision and sensitivity)          0.81484       0.74005
# GI(Gini index)                                                    0.54447       0.54447
# GM(G-mean geometric mean of specificity and sensitivity)          0.76562       0.76562
# IBA(Index of balanced accuracy)                                   0.70445       0.46788
# ICSI(Individual classification success index)                     0.63358       0.48713
# IS(Information score)                                             0.48218       0.84043
# J(Jaccard index)                                                  0.68478       0.58296
# LS(Lift score)                                                    1.39685       1.79058
# MCC(Matthews correlation coefficient)                             0.56013       0.56013
# MCCI(Matthews correlation coefficient interpretation)             Moderate      Moderate
# MCEN(Modified confusion entropy)                                  0.80859       0.90136
# MK(Markedness)                                                    0.57624       0.57624
# N(Condition negative)                                             785           938
# NLR(Negative likelihood ratio)                                    0.18897       0.37642
# NLRI(Negative likelihood ratio interpretation)                    Fair          Poor
# NPV(Negative predictive value)                                    0.81579       0.76045
# OC(Overlap coefficient)                                           0.87313       0.81579
# OOC(Otsuka-Ochiai coefficient)                                    0.81484       0.74005
# OP(Optimized precision)                                           0.65054       0.65054
# P(Condition positive or support)                                  938           785
# PLR(Positive likelihood ratio)                                    2.65663       5.29172
# PLRI(Positive likelihood ratio interpretation)                    Poor          Fair
# POP(Population)                                                   1723          1723
# PPV(Precision or positive predictive value)                       0.76045       0.81579
# PRE(Prevalence)                                                   0.5444        0.4556
# Q(Yule Q - coefficient of colligation)                            0.86718       0.86718
# QI(Yule Q interpretation)                                         Strong        Strong
# RACC(Random accuracy)                                             0.34029       0.17082
# RACCU(Random accuracy unbiased)                                   0.34192       0.17244
# TN(True negative/correct rejection)                               527           819
# TNR(Specificity or true negative rate)                            0.67134       0.87313
# TON(Test outcome negative)                                        646           1077
# TOP(Test outcome positive)                                        1077          646
# TP(True positive/hit)                                             819           527
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.87313       0.67134
# Y(Youden index)                                                   0.54447       0.54447
# dInd(Distance index)                                              0.3523        0.3523
# sInd(Similarity index)                                            0.75089       0.75089

# %%
# SVC
clf4.fit(X_train, y_train)
y_pred = clf4.predict(X_test)
cal_accuracy(y_test, y_pred)
# Out:
# Accuracy :  77.77132907719094
# Report :                precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80       938
#            1       0.79      0.70      0.74       785
#
#     accuracy                           0.78      1723
#    macro avg       0.78      0.77      0.77      1723
# weighted avg       0.78      0.78      0.78      1723
#
# Predict   0         1
# Actual
# 0         788       150
#
# 1         233       552
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.75808,0.79735)
# ACC Macro                                                         0.77771
# ARI                                                               0.30793
# AUNP                                                              0.77164
# AUNU                                                              0.77164
# Bennett S                                                         0.55543
# CBA                                                               0.73749
# CSI                                                               0.55069
# Chi-Squared                                                       522.42791
# Chi-Squared DF                                                    1
# Conditional Entropy                                               0.74493
# Cramer V                                                          0.55064
# Cross Entropy                                                     1.00116
# F1 Macro                                                          0.77346
# F1 Micro                                                          0.77771
# FNR Macro                                                         0.22836
# FNR Micro                                                         0.22229
# FPR Macro                                                         0.22836
# FPR Micro                                                         0.22229
# Gwet AC1                                                          0.56361
# Hamming Loss                                                      0.22229
# Joint Entropy                                                     1.73924
# KL Divergence                                                     0.00686
# Kappa                                                             0.548
# Kappa 95% CI                                                      (0.50807,0.58792)
# Kappa No Prevalence                                               0.55543
# Kappa Standard Error                                              0.02037
# Kappa Unbiased                                                    0.54693
# Lambda A                                                          0.5121
# Lambda B                                                          0.45442
# Mutual Information                                                0.2302
# NIR                                                               0.5444
# Overall ACC                                                       0.77771
# Overall CEN                                                       0.69391
# Overall J                                                         (1.2633,0.63165)
# Overall MCC                                                       0.55064
# Overall MCEN                                                      0.53701
# Overall RACC                                                      0.50822
# Overall RACCU                                                     0.50938
# P-Value                                                           None
# PPV Macro                                                         0.77906
# PPV Micro                                                         0.77771
# Pearson C                                                         0.48235
# Phi-Squared                                                       0.30321
# RCI                                                               0.23152
# RR                                                                861.5
# Reference Entropy                                                 0.9943
# Response Entropy                                                  0.97513
# SOA1(Landis & Koch)                                               Moderate
# SOA2(Fleiss)                                                      Intermediate to Good
# SOA3(Altman)                                                      Moderate
# SOA4(Cicchetti)                                                   Fair
# SOA5(Cramer)                                                      Relatively Strong
# SOA6(Matthews)                                                    Moderate
# Scott PI                                                          0.54693
# Standard Error                                                    0.01002
# TNR Macro                                                         0.77164
# TNR Micro                                                         0.77771
# TPR Macro                                                         0.77164
# TPR Micro                                                         0.77771
# Zero-one Loss                                                     383
#
# Class Statistics :
#
# Classes                                                           0             1
# ACC(Accuracy)                                                     0.77771       0.77771
# AGF(Adjusted F-score)                                             0.7963        0.75073
# AGM(Adjusted geometric mean)                                      0.74812       0.79379
# AM(Difference between automatic and manual classification)        83            -83
# AUC(Area under the ROC curve)                                     0.77164       0.77164
# AUCI(AUC value interpretation)                                    Good          Good
# AUPR(Area under the PR curve)                                     0.80594       0.74475
# BCD(Bray-Curtis dissimilarity)                                    0.02409       0.02409
# BM(Informedness or bookmaker informedness)                        0.54327       0.54327
# CEN(Confusion entropy)                                            0.64919       0.75282
# DOR(Diagnostic odds ratio)                                        12.44567      12.44567
# DP(Discriminant power)                                            0.60372       0.60372
# DPI(Discriminant power interpretation)                            Poor          Poor
# ERR(Error rate)                                                   0.22229       0.22229
# F0.5(F0.5 score)                                                  0.78455       0.76816
# F1(F1 score - harmonic mean of precision and sensitivity)         0.80449       0.74243
# F2(F2 score)                                                      0.82548       0.71838
# FDR(False discovery rate)                                         0.22821       0.21368
# FN(False negative/miss/type 2 error)                              150           233
# FNR(Miss rate or false negative rate)                             0.15991       0.29682
# FOR(False omission rate)                                          0.21368       0.22821
# FP(False positive/type 1 error/false alarm)                       233           150
# FPR(Fall-out or false positive rate)                              0.29682       0.15991
# G(G-measure geometric mean of precision and sensitivity)          0.80522       0.74359
# GI(Gini index)                                                    0.54327       0.54327
# GM(G-mean geometric mean of specificity and sensitivity)          0.76859       0.76859
# IBA(Index of balanced accuracy)                                   0.67161       0.50986
# ICSI(Individual classification success index)                     0.61188       0.48951
# IS(Information score)                                             0.50355       0.78736
# J(Jaccard index)                                                  0.67293       0.59037
# LS(Lift score)                                                    1.4177        1.72591
# MCC(Matthews correlation coefficient)                             0.55064       0.55064
# MCCI(Matthews correlation coefficient interpretation)             Moderate      Moderate
# MCEN(Modified confusion entropy)                                  0.84325       0.92308
# MK(Markedness)                                                    0.55812       0.55812
# N(Condition negative)                                             785           938
# NLR(Negative likelihood ratio)                                    0.22741       0.35332
# NLRI(Negative likelihood ratio interpretation)                    Poor          Poor
# NPV(Negative predictive value)                                    0.78632       0.77179
# OC(Overlap coefficient)                                           0.84009       0.78632
# OOC(Otsuka-Ochiai coefficient)                                    0.80522       0.74359
# OP(Optimized precision)                                           0.68901       0.68901
# P(Condition positive or support)                                  938           785
# PLR(Positive likelihood ratio)                                    2.83033       4.39725
# PLRI(Positive likelihood ratio interpretation)                    Poor          Poor
# POP(Population)                                                   1723          1723
# PPV(Precision or positive predictive value)                       0.77179       0.78632
# PRE(Prevalence)                                                   0.5444        0.4556
# Q(Yule Q - coefficient of colligation)                            0.85125       0.85125
# QI(Yule Q interpretation)                                         Strong        Strong
# RACC(Random accuracy)                                             0.3226        0.18562
# RACCU(Random accuracy unbiased)                                   0.32318       0.18621
# TN(True negative/correct rejection)                               552           788
# TNR(Specificity or true negative rate)                            0.70318       0.84009
# TON(Test outcome negative)                                        702           1021
# TOP(Test outcome positive)                                        1021          702
# TP(True positive/hit)                                             788           552
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.84009       0.70318
# Y(Youden index)                                                   0.54327       0.54327
# dInd(Distance index)                                              0.33715       0.33715
# sInd(Similarity index)                                            0.7616        0.7616

# %%
# save the model to disk
filename = 'final_AD_Model.sav'
pickle.dump(clf7, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.7933836331979106

# %% [markdown]
# # Observations

# %% [markdown]
# * It is known that Feature Scaling improves performance of:
#     1. Gradient Descent Based Algorithms (like  linear regression, logistic regression, and neural network, etc.)
#     2. Distance-Based Algorithms (like KNN, K-means, and SVM, etc.)
#
# * It is also known that Tree-Based Algorithms (like Decision Tree, and Random Forest, etc.) are fairly insensitive/invariant to the scale of the features.
#
# * Let's see if these two properties hold true in our case or not!!

# %% [markdown]
# ## Only MFCCs

# %% [markdown]
# |              | Logistic Regression | SVM Classifier | Perceptron | MLP Classifier |
# |--------------|---------------------|----------------|------------|----------------|
# | Original     | 62                  | 64             | 56         | 69             |
# | Normalized   | 55                  | 55             | 51         | 55             |
# | Standardized | 62                  | 78             | 53         | 78             |

# %% [markdown]
# |              | Decision Tree (Gini) | Decision Tree (Entropy) | Random Forest |
# |--------------|----------------------|-------------------------|---------------|
# | Original     | 72                   | 72                      | 79            |
# | Normalized   | 51                   | 51                      | 52            |
# | Standardized | 71                   | 72                      | 79            |

# %% [markdown]
# ## Other 5 Features

# %% [markdown]
# |              | Logistic Regression | SVM Classifier | Perceptron | MLP Classifier |
# |--------------|---------------------|----------------|------------|----------------|
# | Original     | 55                  | 55             | 52         | 54             |
# | Normalized   | 55                  | 55             | 52         | 55             |
# | Standardized | 57                  | 59             | 51         | 61             |

# %% [markdown]
# |              | Decision Tree (Gini) | Decision Tree (Entropy) | Random Forest |
# |--------------|----------------------|-------------------------|---------------|
# | Original     | 58                   | 58                      | 61            |
# | Normalized   | 50                   | 51                      | 52            |
# | Standardized | 57                   | 58                      | 61            |

# %% [markdown]
# ## All Features

# %% [markdown]
# |              | Logistic Regression | SVM Classifier | Perceptron | MLP Classifier |
# |--------------|---------------------|----------------|------------|----------------|
# | Original     | 61                  | 55             | 53         | 55             |
# | Normalized   | 55                  | 55             | 52         | 55             |
# | Standardized | 62                  | 78             | 54         | 80             |

# %% [markdown]
# |              | Decision Tree (Gini) | Decision Tree (Entropy) | Random Forest |
# |--------------|----------------------|-------------------------|---------------|
# | Original     | 72                   | 73                      | 79            |
# | Normalized   | 51                   | 51                      | 52            |
# | Standardized | 72                   | 73                      | 79            |

# %% [markdown]
# * It is evident from the tables above that, ML models when trained on:
# 1. scaled (standardized to be specific) features, perform a little better than when trained on unscaled features (for Gradient Descent Based and Distance-Based algorithms)
# 2. unscaled features, perform better/equally than when trained on scaled features (for Tree-Based Algorithms)
